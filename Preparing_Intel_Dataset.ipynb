# %%
import pandas as pd

# %%
df = pd.read_json("C:/Users/91812/Electronics_5.json", lines=True)

# %%
df.head(5)
# Out:
#    overall vote  verified   reviewTime      reviewerID        asin  \
# 0        5   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1        3    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2        5    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3        5   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4        3    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
#
#                             style      reviewerName  \
# 0       {'Format:': ' Hardcover'}      D. C. Carrad
# 1  {'Format:': ' Kindle Edition'}               Evy
# 2       {'Format:': ' Paperback'}             Kcorn
# 3       {'Format:': ' Hardcover'}   Caf Girl Writes
# 4       {'Format:': ' Hardcover'}  W. Shane Schmidt
#
#                                           reviewText  \
# 0  This is the best novel I have read in 2 or 3 y...
# 1  Pages and pages of introspection, in the style...
# 2  This is the kind of novel to read when you hav...
# ...

# %%
df.shape
# Out:
# (6739590, 12)

# %%
df = df.head(150000)

# %%
df
# Out:
#         overall vote  verified   reviewTime      reviewerID        asin  \
# 0             5   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1             3    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2             5    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3             5   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4             3    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
# ...         ...  ...       ...          ...             ...         ...
# 149995        5    3      True   04 4, 2014  A2DX28UI6GWL7O  B00008Y0U5
# 149996        4  NaN      True   04 3, 2014  A1U7RNEQX9DLZV  B00008Y0U5
# 149997        4  NaN      True  03 28, 2014  A1MYL611XLASZG  B00008Y0U5
# 149998        5  NaN      True  03 20, 2014  A3FVGL3Q5S7U21  B00008Y0U5
# 149999        4  NaN      True  05 13, 2017  A2F8G94DC04H2R  B00008Y0VN
#
#                                  style      reviewerName  \
# ...

# %%
df.to_csv('intel_electronics_review.csv', index=False)

# %%
df = pd.read_csv('intel_electronics_review.csv')

df
# Out:
#         overall vote  verified   reviewTime      reviewerID        asin  \
# 0             5   67      True  09 18, 1999   AAP7PPBU72QFM  0151004714
# 1             3    5      True  10 23, 2013  A2E168DTVGE6SV  0151004714
# 2             5    4     False   09 2, 2008  A1ER5AYS3FQ9O3  0151004714
# 3             5   13     False   09 4, 2000  A1T17LMQABMBN5  0151004714
# 4             3    8      True   02 4, 2000  A3QHJ0FXK33OBE  0151004714
# ...         ...  ...       ...          ...             ...         ...
# 149995        5    3      True   04 4, 2014  A2DX28UI6GWL7O  B00008Y0U5
# 149996        4  NaN      True   04 3, 2014  A1U7RNEQX9DLZV  B00008Y0U5
# 149997        4  NaN      True  03 28, 2014  A1MYL611XLASZG  B00008Y0U5
# 149998        5  NaN      True  03 20, 2014  A3FVGL3Q5S7U21  B00008Y0U5
# 149999        4  NaN      True  05 13, 2017  A2F8G94DC04H2R  B00008Y0VN
#
#                                  style      reviewerName  \
# ...
